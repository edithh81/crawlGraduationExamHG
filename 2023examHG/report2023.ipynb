# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('rawHG2023.csv')
df.head()
# Out:
#        Code  Toan  NguVan  NgoaiNgu  VatLi  HoaHoc  SinhHoc  KHTN  DiaLi  \
# 0  64000001   6.8    8.00       7.0   6.50     7.0     6.25  6.58    NaN
# 1  64000002   2.4    5.00       NaN    NaN     NaN      NaN   NaN   5.25
# 2  64000003   7.4    7.75       6.4    NaN     NaN      NaN   NaN   7.00
# 3  64000004   5.6    6.50       5.0    NaN     NaN      NaN   NaN   5.25
# 4  64000005   5.2    6.25       4.0   5.75     5.5     6.00  5.75    NaN
#
#    LichSu  GDCD  KHXH
# 0     NaN   NaN   NaN
# 1    4.50   NaN   NaN
# 2    8.25   9.5  8.25
# 3    7.50   8.5  7.08
# 4     NaN   NaN   NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6674 entries, 0 to 6673
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Code      6674 non-null   int64
#  1   Toan      6451 non-null   float64
#  2   NguVan    6581 non-null   float64
#  3   NgoaiNgu  6116 non-null   float64
#  4   VatLi     1870 non-null   float64
#  5   HoaHoc    1884 non-null   float64
#  6   SinhHoc   1858 non-null   float64
#  7   KHTN      1837 non-null   float64
#  8   DiaLi     4731 non-null   float64
#  9   LichSu    4745 non-null   float64
#  10  GDCD      4271 non-null   float64
#  11  KHXH      4271 non-null   float64
# dtypes: float64(11), int64(1)
# memory usage: 625.8 KB

# %%
df['KhoiA00']=df['VatLi']+df['HoaHoc']+df['Toan']
df['KhoiA01']=df['VatLi']+df['NgoaiNgu']+df['Toan']
df['KhoiB00']=df['SinhHoc']+df['HoaHoc']+df['Toan']
df['KhoiC00']=df['NguVan']+df['LichSu']+df['DiaLi']
df['KhoiD00']=df['NguVan']+df['NgoaiNgu']+df['Toan']
df['KhoiD07']=df['NgoaiNgu']+df['HoaHoc']+df['Toan']
df.head()
# Out:
#        Code  Toan  NguVan  NgoaiNgu  VatLi  HoaHoc  SinhHoc  KHTN  DiaLi  \
# 0  64000001   6.8    8.00       7.0   6.50     7.0     6.25  6.58    NaN
# 1  64000002   2.4    5.00       NaN    NaN     NaN      NaN   NaN   5.25
# 2  64000003   7.4    7.75       6.4    NaN     NaN      NaN   NaN   7.00
# 3  64000004   5.6    6.50       5.0    NaN     NaN      NaN   NaN   5.25
# 4  64000005   5.2    6.25       4.0   5.75     5.5     6.00  5.75    NaN
#
#    LichSu  GDCD  KHXH  KhoiA00  KhoiA01  KhoiB00  KhoiC00  KhoiD00  KhoiD07
# 0     NaN   NaN   NaN    20.30    20.30    20.05      NaN    21.80     20.8
# 1    4.50   NaN   NaN      NaN      NaN      NaN    14.75      NaN      NaN
# 2    8.25   9.5  8.25      NaN      NaN      NaN    23.00    21.55      NaN
# 3    7.50   8.5  7.08      NaN      NaN      NaN    19.25    17.10      NaN
# 4     NaN   NaN   NaN    16.45    14.95    16.70      NaN    15.45     14.7

# %%
df['HoaHoc'].max()
# Out:
# 10.0

# %%
df.loc[df.HoaHoc==10.0]
# Out:
#           Code  Toan  NguVan  NgoaiNgu  VatLi  HoaHoc  SinhHoc  KHTN  DiaLi  \
# 2063  64002064   8.2     6.0       6.0   7.25    10.0      7.5  8.25    NaN
#
#       LichSu  GDCD  KHXH  KhoiA00  KhoiA01  KhoiB00  KhoiC00  KhoiD00  KhoiD07
# 2063     NaN   NaN   NaN    25.45    21.45     25.7      NaN     20.2     24.2

# %%
df.to_csv('cleanedHG.csv')

# %%
df=pd.read_csv('cleanedHG.csv')

# %%
df['KhoiA00'].max()
# Out:
# 27.2

# %%
df=pd.read_csv("cleanedHG.csv")

# %%
df['ALL']=df['Toan']+df['NguVan']+df['NgoaiNgu']+df['VatLi']+df['HoaHoc']+df['DiaLi']+df['GDCD']+df['LichSu']+df['SinhHoc']

# %%
df.head()
# Out:
#    Unnamed: 0      Code  Toan  NguVan  NgoaiNgu  VatLi  HoaHoc  SinhHoc  KHTN  \
# 0           0  64000001   6.8    8.00       7.0   6.50     7.0     6.25  6.58
# 1           1  64000002   2.4    5.00       NaN    NaN     NaN      NaN   NaN
# 2           2  64000003   7.4    7.75       6.4    NaN     NaN      NaN   NaN
# 3           3  64000004   5.6    6.50       5.0    NaN     NaN      NaN   NaN
# 4           4  64000005   5.2    6.25       4.0   5.75     5.5     6.00  5.75
#
#    DiaLi  LichSu  GDCD  KHXH  KhoiA00  KhoiA01  KhoiB00  KhoiC00  KhoiD00  \
# 0    NaN     NaN   NaN   NaN    20.30    20.30    20.05      NaN    21.80
# 1   5.25    4.50   NaN   NaN      NaN      NaN      NaN    14.75      NaN
# 2   7.00    8.25   9.5  8.25      NaN      NaN      NaN    23.00    21.55
# 3   5.25    7.50   8.5  7.08      NaN      NaN      NaN    19.25    17.10
# 4    NaN     NaN   NaN   NaN    16.45    14.95    16.70      NaN    15.45
#
#    KhoiD07  ALL
# 0     20.8  NaN
# 1      NaN  NaN
# ...

# %%
df.to_csv('cleanedHG.csv')

# %%
df['ALL'].max()
# Out:
# nan

# %%
df=pd.read_csv("cleanedHG.csv")

# %%
df['ALL'].pop
# Out:
# <bound method Series.pop of 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 6669   NaN
# 6670   NaN
# 6671   NaN
# 6672   NaN
# 6673   NaN
# Name: ALL, Length: 6674, dtype: float64>

# %%
df['ALLtn']=df['Toan']+df['NguVan']+df['NgoaiNgu']+df['VatLi']+df['HoaHoc']+df['SinhHoc']
df['ALLxh']=df['Toan']+df['NguVan']+df['NgoaiNgu']+df['DiaLi']+df['GDCD']+df['LichSu']

# %%
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0      Code  Toan  NguVan  NgoaiNgu  VatLi  HoaHoc  \
# 0             0           0  64000001   6.8    8.00       7.0   6.50     7.0
# 1             1           1  64000002   2.4    5.00       NaN    NaN     NaN
# 2             2           2  64000003   7.4    7.75       6.4    NaN     NaN
# 3             3           3  64000004   5.6    6.50       5.0    NaN     NaN
# 4             4           4  64000005   5.2    6.25       4.0   5.75     5.5
#
#    SinhHoc  KHTN  ...  KHXH  KhoiA00  KhoiA01  KhoiB00  KhoiC00  KhoiD00  \
# 0     6.25  6.58  ...   NaN    20.30    20.30    20.05      NaN    21.80
# 1      NaN   NaN  ...   NaN      NaN      NaN      NaN    14.75      NaN
# 2      NaN   NaN  ...  8.25      NaN      NaN      NaN    23.00    21.55
# 3      NaN   NaN  ...  7.08      NaN      NaN      NaN    19.25    17.10
# 4     6.00  5.75  ...   NaN    16.45    14.95    16.70      NaN    15.45
#
#    KhoiD07  ALL  ALLtn  ALLxh
# 0     20.8  NaN  41.55    NaN
# ...

# %%
df['ALLtn'].max()
# Out:
# 51.599999999999994

# %%
df['ALLxh'].max()
# Out:
# 55.1

# %%
df.to_csv('cleanedHG.csv')
